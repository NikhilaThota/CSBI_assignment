# %% [markdown]
# ## Introduction
#
# ** The organization is an office supply retail company with presence all across the USA. The company sells products such as office supplies, furniture and equipment/ machines. It generated $ in 2017.**

# %% [markdown]
# **Import the required libraries**

# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

# %% [markdown]
# - **Every sheet is read into a seperate dataframe and is given the same name as the sheet name**
# - **To load the data correctly the first four rows are eliminated and the first column is skipped as well**

# %%
# Read orders csv into orders dataframe
orders = pd.read_excel('E:\Data Science\Cox Assignment\\02. Data Analyst II Exercise_Dataset.xls', sheetname='Orders', 
                       skiprows=4, usecols= range(1,22))

# %% [markdown]
# **After loading the data into dataframe, it is a good practice to check if the data is loaded properly. head() and tail() methods dispaly the first five and last five rows of the dataframe respectively**

# %%
orders.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
orders.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster
#
#        ...    Postal Code  Region       Product ID         Category  \
# ...

# %% [markdown]
# **Let us repeat the same steps for other sheets as well**

# %%
# Returns csv is read into returns dataframe
returns = pd.read_excel('E:\Data Science\Cox Assignment\\02. Data Analyst II Exercise_Dataset.xls', sheetname='Returns', 
                       skiprows=4, usecols= range(1,3))

# %%
returns.head()
# Out:
#   Returned        Order ID
# 0      Yes  CA-2017-153822
# 1      Yes  CA-2017-129707
# 2      Yes  CA-2014-152345
# 3      Yes  CA-2015-156440
# 4      Yes  US-2017-155999

# %%
returns.tail()
# Out:
#     Returned        Order ID
# 291      Yes  CA-2015-101910
# 292      Yes  CA-2017-156958
# 293      Yes  CA-2016-105585
# 294      Yes  CA-2016-148796
# 295      Yes  CA-2015-149636

# %%
# People csv is read into people dataframe
people = pd.read_excel('E:\Data Science\Cox Assignment\\02. Data Analyst II Exercise_Dataset.xls',sheetname='People',
                       skiprows=4, usecols= range(1,3))

# %%
people
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
# Quota csv is read into quota dataframe
quota = pd.read_excel('E:\Data Science\Cox Assignment\\02. Data Analyst II Exercise_Dataset.xls',sheetname='Quota',
                       skiprows=4, usecols= range(1,3))

# %%
quota.head()
# Out:
#      US State    Quota
# 0     Alabama   150000
# 1      Alaska    35000
# 2     Arizona   120000
# 3    Arkansas   100000
# 4  California  1500000

# %%
quota.tail()
# Out:
#          US State   Quota
# 44       Virginia  148000
# 45     Washington  480000
# 46  West Virginia   34500
# 47      Wisconsin  150000
# 48        Wyoming   24000

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# - **info() method gives many details about the dataframe such as datatypes of each column, no. of non null values, nunber of rows etc.**
# - **All the datatypes seems to be assigned correctly for all the dataframes**
# - **As we can see there are no null values**

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
# Row ID           9994 non-null int64
# Order ID         9994 non-null object
# Order Date       9994 non-null datetime64[ns]
# Ship Date        9994 non-null datetime64[ns]
# Ship Mode        9994 non-null object
# Customer ID      9994 non-null object
# Customer Name    9994 non-null object
# Segment          9994 non-null object
# Country          9994 non-null object
# City             9994 non-null object
# State            9994 non-null object
# Postal Code      9994 non-null int64
# Region           9994 non-null object
# Product ID       9994 non-null object
# Category         9994 non-null object
# Sub-Category     9994 non-null object
# Product Name     9994 non-null object
# Sales            9994 non-null float64
# Quantity         9994 non-null int64
# Discount         9994 non-null float64
# Profit           9994 non-null float64
# ...

# %%
returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 2 columns):
# Returned    296 non-null object
# Order ID    296 non-null object
# dtypes: object(2)
# memory usage: 4.7+ KB

# %%
people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
# Person    4 non-null object
# Region    4 non-null object
# dtypes: object(2)
# memory usage: 144.0+ bytes

# %%
quota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
# US State    49 non-null object
# Quota       49 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 864.0+ bytes

# %% [markdown]
# **Though it is clear that there are no null values in the dataframes, it is a good practice to use isnull() method to be sure**

# %%
# Find for null any values
print(orders.isnull().values.any())
print(returns.isnull().values.any())
print(people.isnull().values.any())
print(quota.isnull().values.any())
# Out:
# False
# False
# False
# False

# %% [markdown]
# **Let us also look at how many rows and columns are in each dataframe**

# %%
print(orders.shape)
print(returns.shape)
print(people.shape)
print(quota.shape)
# Out:
# (9994, 21)
# (296, 2)
# (4, 2)
# (49, 2)

# %% [markdown]
# **I decided to rename the coulumns that are seperated by spaces and replace the space with underscore. This way it is much easier to access a column**

# %%
# Rename a few columns
orders= orders.rename(columns= {'Row ID':'Row_ID','Order ID':'Order_ID','Order Date':'Order_Date','Ship Date':'Ship_Date',
                                'Ship Mode':'Ship_Mode','Customer ID':'Customer_ID','Customer Name':'Customer_Name',
                                'Postal Code':'Postal_Code','Product ID':'Product_ID','Sub-Category':'Sub_Category',
                                'Product Name':'Product_Name'})

# %%
orders.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal_Code  Region       Product_ID         Category Sub_Category  \
# ...

# %%
# Rename a few columns
returns =returns.rename(columns={'Order ID':'Order_ID'})

# %%
returns.head()
# Out:
#   Returned        Order_ID
# 0      Yes  CA-2017-153822
# 1      Yes  CA-2017-129707
# 2      Yes  CA-2014-152345
# 3      Yes  CA-2015-156440
# 4      Yes  US-2017-155999

# %%
# Rename a few columns
people = people.rename(columns={'Person':'Sales_Person'})

# %%
people.head()
# Out:
#         Sales_Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
# Rename a few columns
quota=quota.rename(columns={'US State':'State'})

# %%
quota.head()
# Out:
#         State    Quota
# 0     Alabama   150000
# 1      Alaska    35000
# 2     Arizona   120000
# 3    Arkansas   100000
# 4  California  1500000

# %% [markdown]
# **During my investigation I found that there are a few inconsistencies in the State coulmn in orders and quota dataframes**
# - **'Washington D.C.'** is one of the states in **_quota_** dataframe under the _State_ column , but in **_orders_** dataframe same state is defined as **'District of Columbia'**. I **renamed** **'Washington D.C.'** in **_quota_** to **'District of Columbia'** to avoid inconsistency in data.
# - **_Massachusetts_** was indiacted as **_Mass_** in **_quota_** dataframe. It is renamed to **_Massachusetts_**
# - No quota is defined for the state of **_Delaware_**, but still the Sales person made sales in that state.
# - Quota is assigned to **_Alaska_** state, but no sales were made in **_Alaska_** from 2014-2017

# %%
# Find out unique State names for comparison
print(orders.State.unique())
print(quota.State.unique())
# Out:
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi' 'Arkansas'
#  'Montana' 'New Hampshire' 'Maryland' 'District of Columbia' 'Kansas'
#  'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota' 'Wyoming'
#  'West Virginia']
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Washington D.C.' 'Florida' 'Georgia' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland' 'Mass'
#  'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana' 'Nebraska'
#  'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
# ...

# %%
quota['State'].replace(['Washington D.C.','Mass'],['District of Columbia','Massachusetts'],inplace=True)

# %%
quota.State.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'District of Columbia', 'Florida',
#        'Georgia', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia',
#        'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# **Extracted year from Order_Date coulmn in orders dataframe**

# %%
# Added Year column to orders
orders['Year'] = orders['Order_Date'].dt.year
orders.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...   South
# 1      Claire Gute   Consumer  United States        Henderson  ...   South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...    West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...   South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...   South
#
#         Product_ID         Category Sub_Category  \
# ...

# %%
# Join orders and returns
orders = returns.merge(orders,on='Order_ID',how='right')
#orders.to_csv('E:\Data Science\ordersexcel.csv', index=False)

# %%
mask = orders['Returned']=='Yes'
orders.loc[mask, 'Sales'] = 0

# %%
mask = orders['Sales']== 0
orders.loc[mask, 'Profit'] = 0

# %%
orders.drop(['Returned'],axis=1,inplace=True)

# %%
orders_r = orders

# %%
orders = orders[orders['Sales']>0]

# %% [markdown]
# ## Data Story
#
# **I decided to give company a name, let's call it _Office Pro_**

# %%
# Categories and thier sales in 2017
orders_category_2017 = orders[['Category','Sales']][(orders['Year']==2017)]

# %% [markdown]
# ** 1. What kind of products does Office Pro sell?**
# - _Technology produced highest sales in 2017_

# %%
plt.figure(figsize=(8,6))
sns.set_style('whitegrid')
g = sns.lvplot(x='Category',y='Sales',data=orders_category_2017)
g.set(xlabel='Product Category', ylabel= '2017 Sales ')
g.set_title('Office Pro Product Categories and thier Sales in 2017')

# %%
#plt.figure(figsize=(8,6))
#sns.set_style('white')
#g= sns.barplot(x='Year', y='Sales', hue='Category',data=orders,palette='pastel')
#g.set(xlabel='Year', ylabel='Average Sales ($))')
#g.set_title('Average Sales of all Categories')

# %% [markdown]
# **2. What products are more popular with Sales in Office Pro**
#
# - _As we saw earlier products under Technology category contribute to most part of the sales. Likewise most of the top products of Office Pro are machines, copiers etc._

# %%
# overall top product
products=orders[['Product_Name','Sales']]
products_grouped = products.groupby(['Product_Name'],as_index=False).sum()
products_top = products_grouped.sort_values(by='Sales',ascending=False).head(10)
products_top
# Out:
#                                           Product_Name      Sales
# 400              Canon imageCLASS 2200 Advanced Copier  47599.864
# 645  Fellowes PB500 Electric Punch Plastic Comb Bin...  27453.384
# 439  Cisco TelePresence System EX90 Videoconferenci...  22638.480
# 681         GBC DocuBind TL300 Electric Binding System  19823.479
# 781       HON 5400 Series Task Chairs for Big and Tall  19417.146
# 683   GBC Ibimaster 500 Manual ProClick Binding System  19024.500
# 800               Hewlett Packard LaserJet 3310 Copier  18839.686
# 782  HP Designjet T520 Inkjet Large Format Printer ...  18374.895
# 807        High Speed Automatic Electric Letter Opener  17030.312
# 979          Lexmark MX611dhe Monochrome Laser Printer  16829.901

# %%
plt.figure(figsize=(15,6))
sns.set_style('white')
g= sns.barplot(x='Product_Name', y='Sales',data=products_top,palette='pastel')
g.set_xlabel('Product Name',fontsize=3)
g.set_xticklabels(g.get_xticklabels(),rotation=90)
g.set_ylabel('Average Sales ($))')
g.set_title('Average Sales of top ten Products')
plt.legend(['Canon imageCLASS','Fellowes PB500','Cisco TelePresence System','GBC DocuBind TL300','HON 5400 Series',
           'GBC Ibimaster 500','Hewlett Packard LaserJet','HP Designjet T520','High Speed Automatic Electric',
           'Lexmark MX611dhe Monochrome'],loc = "upper right")
#plt.tick_params(axis='x',bottom='off',labelsize=0)

# %%
# overall top product
products_profit=orders[['Product_Name','Profit','Sub_Category']]
products_profit_grouped = products_profit.groupby(['Product_Name','Sub_Category'],as_index=False).mean()
products_profit_top = products_profit_grouped.sort_values(by='Profit',ascending=False).head(10)
products_profit_top
# Out:
#                                            Product_Name Sub_Category  \
# 400               Canon imageCLASS 2200 Advanced Copier      Copiers
# 164                   Ativa V4110MDD Micro-Cut Shredder     Machines
# 401   Canon imageCLASS MF7460 Monochrome Digital Las...     Machines
# 19     3D Systems Cube Printer, 2nd Generation, Magenta     Machines
# 1832                  Zebra ZM400 Thermal Label Printer     Machines
# 806   Hewlett-Packard Desktjet 6988DT Refurbished Pr...     Machines
# 802   Hewlett-Packard Deskjet 3050a All-in-One Color...     Machines
# 427                  Cisco 9971 IP Video Phone Charcoal     Machines
# 782   HP Designjet T520 Inkjet Large Format Printer ...     Machines
# 396                  Canon PC1060 Personal Laser Copier      Copiers
#
#            Profit
# 400   4619.986800
# 164   2400.965700
# 401   1995.990000
# 19    1858.985700
# 1832  1671.768000
# 806   1668.205000
# 802   1459.200000
# 427   1416.800000
# 782   1364.992200
# ...

# %% [markdown]
# **Top profit making product over all the years has been Canon imageCLASS 2200 Advanced Copier bringing in average of 4619.986  each time it has been sold

# %%
products_profit=orders[['Product_Name','Profit','Sub_Category']][(orders['Year']==2017)]
products_profit_grouped = products_profit.groupby(['Product_Name','Sub_Category'],as_index=False).mean()
products_profit_top = products_profit_grouped.sort_values(by='Profit',ascending=False).head(10)
products_profit_top
# Out:
#                                           Product_Name Sub_Category     Profit
# 320              Canon imageCLASS 2200 Advanced Copier      Copiers  4479.9872
# 646  Hewlett-Packard Desktjet 6988DT Refurbished Pr...     Machines  1668.2050
# 18    3D Systems Cube Printer, 2nd Generation, Magenta     Machines  1351.9896
# 643               Hewlett Packard LaserJet 3310 Copier      Copiers   905.9849
# 539            GBC DocuBind 200 Manual Binding Machine      Binders   884.0580
# 316                      Canon Image Class D660 Copier      Copiers   845.9859
# 317                 Canon Imageclass D680 Copier / Fax      Copiers   839.9880
# 516  Fellowes Powershred HS-440 4-Sheet High Securi...     Machines   767.2005
# 351            ClearOne CHATAttach 160 - speaker phone       Phones   743.9880
# 819  Logitech Z-906 Speaker sys - home theater - 5....  Accessories   659.9800

# %%
products_profit=orders[['Product_Name','Profit','Sub_Category']][(orders['Year']==2017)]
products_profit_grouped = products_profit.groupby(['Product_Name','Sub_Category'],as_index=False).mean()
products_profit_top = products_profit_grouped.sort_values(by='Profit',ascending=False).tail(10)
products_profit_top
# Out:
#                                            Product_Name Sub_Category  \
# 232                        Balt Solid Wood Round Tables       Tables
# 1198       Swingline SM12-08 MicroCut Jam Free Shredder     Machines
# 290   BoxOffice By Design Rectangular and Half-Moon ...       Tables
# 515   Fellowes PB500 Electric Punch Plastic Comb Bin...      Binders
# 336   Chromcraft Bull-Nose Wood Oval Conference Tabl...       Tables
# 477   Epson TM-T88V Direct Thermal Printer - Monochr...     Machines
# 547    GBC Ibimaster 500 Manual ProClick Binding System      Binders
# 784           Lexmark MX611dhe Monochrome Laser Printer     Machines
# 708                Ibico EPK-21 Electric Binding System      Binders
# 378           Cubify CubeX 3D Printer Triple Head Print     Machines
#
#           Profit
# 232   -444.25755
# 1198  -479.98800
# 290   -493.28125
# 515   -508.39600
# 336   -550.98000
# 477   -935.95950
# 547  -1141.47000
# 784  -1359.99200
# 708  -2929.48450
# 378  -3839.99040

# %%
products_profit=orders[['Product_Name','Profit','Sub_Category']][(orders['Year']==2016)]
products_profit_grouped = products_profit.groupby(['Product_Name','Sub_Category'],as_index=False).mean()
products_profit_top = products_profit_grouped.sort_values(by='Profit',ascending=False).head(10)
products_profit_top
# Out:
#                                           Product_Name Sub_Category     Profit
# 289              Canon imageCLASS 2200 Advanced Copier      Copiers  4759.9864
# 577  HP Designjet T520 Inkjet Large Format Printer ...     Machines  2799.9840
# 121                  Ativa V4110MDD Micro-Cut Shredder     Machines  2400.9657
# 12    3D Systems Cube Printer, 2nd Generation, Magenta     Machines  2365.9818
# 654               Ibico EPK-21 Electric Binding System      Binders  1644.2913
# 591  Hewlett-Packard Deskjet 3050a All-in-One Color...     Machines  1459.2000
# 590               Hewlett Packard LaserJet 3310 Copier      Copiers  1391.9768
# 205                        Bady BDG101FRU Card Printer     Machines  1159.9855
# 287                 Canon PC1060 Personal Laser Copier      Copiers   944.9865
# 489         GBC DocuBind TL300 Electric Binding System      Binders   843.1706

# %%
products_profit=orders[['Product_Name','Profit','Sub_Category']][(orders['Year']==2016)]
products_profit_grouped = products_profit.groupby(['Product_Name','Sub_Category'],as_index=False).mean()
products_profit_top = products_profit_grouped.sort_values(by='Profit',ascending=False).tail(10)
products_profit_top
# Out:
#                                           Product_Name Sub_Category  \
# 601  Hon 2090 “Pillow Soft” Series Mid Back Swivel/...       Chairs
# 204                              BPI Conference Tables       Tables
# 592        High Speed Automatic Electric Letter Opener     Supplies
# 968  Riverside Palais Royal Lawyers Bookcase, Royal...    Bookcases
# 268  Brother MFC-9340CDW LED All-In-One Printer, Co...     Machines
# 753  Luxo Professional Fluorescent Magnifier Lamp w...  Furnishings
# 265  Bretford “Just In Time” Height-Adjustable Mult...       Tables
# 711                                              LG G2       Phones
# 879                Okidata MB491 Multifunction Printer     Machines
# 345          Cubify CubeX 3D Printer Double Head Print     Machines
#
#           Profit
# 601  -258.501600
# 204  -273.843750
# 592  -294.755400
# 968  -317.152800
# 268  -319.191600
# 753  -356.728000
# 265  -360.355333
# 711  -374.992500
# 879  -643.710000
# 345 -6599.978000

# %%
products_profit=orders[['Product_Name','Profit','Sub_Category']][(orders['Year']==2015)]
products_profit_grouped = products_profit.groupby(['Product_Name','Sub_Category'],as_index=False).mean()
products_profit_top = products_profit_grouped.sort_values(by='Profit',ascending=False).head(10)
products_profit_top
# Out:
#                                            Product_Name Sub_Category  \
# 411   Fellowes PB500 Electric Punch Plastic Comb Bin...      Binders
# 1190                  Zebra ZM400 Thermal Label Printer     Machines
# 271                  Cisco 9971 IP Video Phone Charcoal     Machines
# 251                  Canon PC1060 Personal Laser Copier      Copiers
# 254                                  Canon PC940 Copier      Copiers
# 249                  Canon Imageclass D680 Copier / Fax      Copiers
# 547                          Hon Pagoda Stacking Chairs       Chairs
# 276                      Cisco SPA525G2 5-Line IP Phone     Machines
# 912   Sanyo Counter Height Refrigerator with Crisper...   Appliances
# 1068     Wilson SignalBoost 841262 DB PRO Amplifier Kit       Phones
#
#           Profit
# 411   1874.71025
# 1190  1671.76800
# 271   1416.80000
# 251   1340.48085
# 254    983.22815
# 249    874.98750
# 547    770.35200
# 276    648.56240
# 912    597.21480
# 1068   539.92500

# %%
products_profit=orders[['Product_Name','Profit','Sub_Category']][(orders['Year']==2015)]
products_profit_grouped = products_profit.groupby(['Product_Name','Sub_Category'],as_index=False).mean()
products_profit_top = products_profit_grouped.sort_values(by='Profit',ascending=False).tail(10)
products_profit_top
# Out:
#                                            Product_Name Sub_Category  \
# 630         Lexmark MarkNet N8150 Wireless Print Server     Machines
# 1001                        Tennsco Single-Tier Lockers      Storage
# 917   Sauder Forest Hills Library with Doors, Woodla...    Bookcases
# 763      O'Sullivan Living Dimensions 5-Shelf Bookcases    Bookcases
# 202                 Bevis Oval Conference Table, Walnut       Tables
# 410         Fellowes PB300 Plastic Comb Binding Machine      Binders
# 550                   Hon Rectangular Conference Tables       Tables
# 436          GBC DocuBind TL300 Electric Binding System      Binders
# 266   Chromcraft Bull-Nose Wood Oval Conference Tabl...       Tables
# 299           Cubify CubeX 3D Printer Double Head Print     Machines
#
#          Profit
# 630   -337.6380
# 1001  -337.8060
# 917   -376.6932
# 763   -437.5404
# 202   -480.2032
# 410   -512.1468
# 550   -525.6405
# 436  -1031.5385
# 266  -1862.3124
# 299  -2639.9912

# %%
products_profit=orders[['Product_Name','Profit','Sub_Category']][(orders['Year']==2014)]
products_profit_grouped = products_profit.groupby(['Product_Name','Sub_Category'],as_index=False).mean()
products_profit_top = products_profit_grouped.sort_values(by='Profit',ascending=False).head(10)
products_profit_top
# Out:
#                                           Product_Name Sub_Category     Profit
# 567               Ibico EPK-21 Electric Binding System      Binders  4630.4755
# 253  Canon imageCLASS MF7460 Monochrome Digital Las...     Machines  1995.9900
# 405        Fellowes PB300 Plastic Comb Binding Machine      Binders  1276.4871
# 107                                     Apple iPhone 5       Phones  1228.1787
# 429          GBC DocuBind P400 Electric Binding System      Binders  1061.5722
# 876                           Samsung Galaxy S4 Active       Phones   909.9818
# 406  Fellowes PB500 Electric Punch Plastic Comb Bin...      Binders   762.5940
# 792  Plantronics Savi W720 Multi-Device Wireless He...  Accessories   742.6320
# 251                      Canon PC1080F Personal Copier      Copiers   701.9883
# 769  Panasonic KX-TG9541B DECT 6.0 Digital 2-Line E...       Phones   661.4559

# %%
products_profit=orders[['Product_Name','Profit','Sub_Category']][(orders['Year']==2014)]
products_profit_grouped = products_profit.groupby(['Product_Name','Sub_Category'],as_index=False).mean()
products_profit_top = products_profit_grouped.sort_values(by='Profit',ascending=False).tail(10)
products_profit_top
# Out:
#                                            Product_Name Sub_Category  \
# 1146  Xerox WorkCentre 6505DN Laser Multifunction Pr...     Machines
# 736          O'Sullivan 4-Shelf Bookcase in Odessa Pine    Bookcases
# 545                     Hon Racetrack Conference Tables       Tables
# 949     StarTech.com 10/100 VDSL2 Ethernet Extender Kit     Machines
# 11    3.6 Cubic Foot Counter Height Office Refrigerator   Appliances
# 427           GBC DocuBind 300 Electric Binding Machine      Binders
# 191                        Balt Solid Wood Round Tables       Tables
# 12       3D Systems Cube Printer, 2nd Generation, White     Machines
# 620           Lexmark MX611dhe Monochrome Laser Printer     Machines
# 275   Cisco TelePresence System EX90 Videoconferenci...     Machines
#
#          Profit
# 1146  -251.9958
# 736   -260.1070
# 545   -299.2614
# 949   -379.5630
# 11    -459.6072
# 427   -515.4604
# 191   -553.6476
# 12    -571.9956
# 620   -934.9945
# 275  -1811.0784

# %% [markdown]
# The above Evidence points to Machines being the most loss making category

# %% [markdown]
# **I added another dimension 'location', below are the top five products with highest sales in cities like Jacksonville, Detroit etc.**

# %%
products_all=orders[['Product_Name','City','Year','Sales']]
products_all_grouped = products_all.groupby(['Product_Name','City','Year'],as_index=False).sum()
products_all_grouped_sort = products_all_grouped.sort_values(by='Sales',ascending=False).head(5)
products_all_grouped_sort
# Out:
#                                            Product_Name           City  Year  \
# 2142  Cisco TelePresence System EX90 Videoconferenci...   Jacksonville  2014
# 1953              Canon imageCLASS 2200 Advanced Copier      Lafayette  2016
# 1954              Canon imageCLASS 2200 Advanced Copier  New York City  2017
# 1955              Canon imageCLASS 2200 Advanced Copier         Newark  2017
# 3355   GBC Ibimaster 500 Manual ProClick Binding System        Detroit  2016
#
#           Sales
# 2142  22638.480
# 1953  17499.950
# 1954  11199.968
# 1955  10499.970
# 3355   9892.740

# %%
plt.figure(figsize=(10,6))
sns.set_style('white')
g= sns.barplot(x='Product_Name', y='Sales',hue='City',data=products_all_grouped_sort,palette='pastel')
g.set(xlabel='Product Name', ylabel='Average Sales ($))')
g.set_title('Average Sales of top ten Products')
plt.tick_params(axis='x',bottom='off',labelsize=7)

# %% [markdown]
# **Most returned products from customers**

# %%
returns_prod1 = orders[['Product_Name','Year']][((orders['Sales']==0)|(orders['Year']==2017))]
returns_prod_grouped1 = pd.DataFrame({'Returned_Products_num' : returns_prod1.groupby( ['Product_Name'])
                                          .size()}).reset_index()
returns_prod_grouped_sort1 = returns_prod_grouped1.sort_values(by='Returned_Products_num',ascending=False).head(10)
returns_prod_grouped_sort1
# Out:
#                                          Product_Name  Returned_Products_num
# 433                                 Easy-staple paper                     16
# 1184                                          Staples                     14
# 1185                          Staples in misc. colors                     12
# 1179                                  Staple envelope                      9
# 1190                          Storex Dura Pro Binders                      8
# 792   Logitech Desktop MK120 Mouse and keyboard Combo                      7
# 618   Global Wood Trimmed Manager's Task Chair, Khaki                      7
# 95                 Adjustable Depth Letter/Legal Cart                      7
# 1193                     Strathmore Photo Mount Cards                      7
# 197       Avery Durable Slant Ring Binders, No Labels                      6

# %%
plt.figure(figsize=(15,6))
g= sns.barplot(x='Product_Name', y='Returned_Products_num',data=returns_prod_grouped_sort1, palette='hls')
g.set(xlabel='Product Name', ylabel='Products returned number')
g.set_xticklabels(g.get_xticklabels(),rotation=90)
g.set_title('Top ten products most reurned by Customers in 2017)')
plt.legend(['Easy-staple paper','Staples','Staple envelope','Staples in misc. colors','Global Wood Trimmed Chair',
            'KI Adjustable-Height Table','Wilson Jones Easy Flow II Sheet Lifters','Staple remover','Staple-based wall hangings',
            'Xerox 191'],loc = "upper right")
#g.set_xticklabels(rotation=25)
plt.tick_params(axis='x',bottom='off',labelsize=10)

# %%
plt.figure(figsize=(15,6))
sns.set_style('white')
g= sns.barplot(x='Product_Name', y='Sales',data=products_top,palette='pastel')
g.set_xlabel('Product Name',fontsize=3)
g.set_xticklabels(g.get_xticklabels(),rotation=90)
g.set_ylabel('Average Sales ($))')
g.set_title('Average Sales of top ten Products')
plt.legend(['Canon imageCLASS','Fellowes PB500','Cisco TelePresence System','GBC DocuBind TL300','HON 5400 Series',
           'GBC Ibimaster 500','Hewlett Packard LaserJet','HP Designjet T520','High Speed Automatic Electric',
           'Lexmark MX611dhe Monochrome'],loc = "upper right")

# %% [markdown]
# **3. Let us see how which sub category is effecting the sales**
#
# - _**The sales definitely went up for all the sub categories in 2017**_
# - _**Furniture:** Bookcases sales went down in 2016 & 2017, and also there is a decrease in sales of Chairs_
# - _**Technology:** Notice a drastic fall in the sales of Machines in 2017!_

# %%
# Grouping sub category data for Technology and Furtinure and Office Supplies
orders_subcat = orders[(orders['Category']=='Technology') | (orders['Category']=='Furniture') | 
                       (orders['Category']=='Office Supplies')]
orders_subcat = orders_subcat[['Category','Sub_Category','Sales','Year']]
orders_subcat_grouped = orders_subcat.groupby(['Category','Sub_Category','Year'],as_index=False).sum()

# %%
plt.figure(figsize=(18,8))
g= sns.factorplot(x='Year', y='Sales', hue='Sub_Category', col='Category',data=orders_subcat_grouped, kind='bar')
g.set(xlabel='Year', ylabel='Average Sales ($))')
#g.set_title('Average Sales of sub category products of Technology and Furniture')

# %% [markdown]
# **4. I am curious to know what was the effect of returns on sales**
#
# - _**Office Supplies** products are the most returned category throughout all periods_
# - _**Inference:** Returns on Furniture and Technology products defineitely increased in 2017_

# %%
orders_returns = orders_r[['Year','Category','Sub_Category']][(orders_r['Sales']==0)]
orders_returns_grouped = pd.DataFrame({'Number_Returned' : orders_returns.groupby( [ 'Year','Category','Sub_Category'])
                                       .size()}).reset_index()

# %%
plt.figure(figsize=(20,8))
g= sns.factorplot(x='Year', y='Number_Returned', hue='Sub_Category', col='Category',data=orders_returns_grouped, kind='bar')
g.set(xlabel='Year', ylabel='Items returned')

# %% [markdown]
# **5. Let us see which Furniture and Technology prodcust were most returned in 2017**
#
# - _Furnishings, Accessories and Phones, Chairs are most returned items_

# %%
orders_cat = orders_r[((orders_r['Category']=='Furniture') | (orders_r['Category']=='Technology')) & 
                          (orders_r['Year']==2017)]
orders_cat_returns = orders_cat[['Year','Category','Sub_Category']]
orders_cat_returns_grouped = pd.DataFrame({'Number_Returned' : orders_cat_returns.groupby(['Year','Category',
                                                'Sub_Category']).size()}).reset_index()

# %%
plt.figure(figsize=(20,6))
sns.set_style('white')
g= sns.factorplot(x='Sub_Category',y='Number_Returned',hue='Category',data=orders_cat_returns_grouped, kind="bar",
                  margin_titles=True, aspect=1.5)
g.set(xlabel='Sub_Category', ylabel='Number of items Returned')
g.set_xticklabels(rotation=90)
#g.title('Office Supplies returned in 2016 & 2017')

# %% [markdown]
# **6. Which segment generates highest sales**
#
# - _Consumer is the highest sales geneartor, followed by Corporate_

# %%
orders_seg = orders[['Segment','Sales','Year']]
orders_seg_grouped = orders_seg.groupby(['Year','Segment'],as_index=False).sum().round(2)

# %%
plt.figure(figsize=(15,6))
g= sns.pointplot(x='Year', y='Sales', hue='Segment',data=orders_seg_grouped, palette='hls')
g.set(xlabel='Year & Segment', ylabel='Total Sales ($)')
g.set_title('Segments Sales from 2014-17')

# %% [markdown]
# ** Consumer segment products are major contributors to the Sales in 2017**

# %%
orders_seg_prod = orders[['Segment','Product_Name','Sales']][(orders['Year']==2017)]
orders_seg_prod_grouped = orders_seg_prod.groupby(['Product_Name','Segment'],as_index=False).sum().round(2)
orders_seg_prod_grouped_sort = orders_seg_prod_grouped.sort_values(by='Sales',ascending=False).head(5)

# %%
plt.figure(figsize=(15,6))
g= sns.barplot(x='Product_Name', y='Sales', hue='Segment',data=orders_seg_prod_grouped_sort, palette='hls')
g.set(xlabel='Segment', ylabel='Total Sales ($)')
g.set_title('Products most bought in each segment in 2017')

# %%
orders_seg_city = orders[['Segment','City','Sales']][(orders['Year']==2017)]
orders_seg_city_grouped = orders_seg_city.groupby(['City','Segment'],as_index=False).sum().round(2)
orders_seg_city_grouped_sort = orders_seg_city_grouped.sort_values(by='Sales',ascending=False).head(10)

# %%
plt.figure(figsize=(15,6))
g= sns.barplot(x='City', y='Sales', hue='Segment',data=orders_seg_city_grouped_sort, palette='muted')
g.set(xlabel='Segment', ylabel='Total Sales ($)')
g.set_title('Highes sales in cities segment wise')

# %% [markdown]
# **7. Which state and/ or city is a major consumer of Office Pro's products**
#
# - _**New York City** has always been the highest sales generator through out the period_
# - _ From 2014 to 2017 Sales improved in **Philadelphia**_
# - _ **California, New York** have been making some decent numbers in the past_

# %%
sales_city = orders[['City','Year','Sales']]
sales_year_city = sales_city.groupby(['City','Year'],as_index=False).sum()
sales_year_city.topfive = sales_year_city.sort_values(['Year','Sales'],ascending=[False, False]).groupby('Year').head(5)

# %%
plt.figure(figsize=(15,6))
g= sns.pointplot(x='Year', y='Sales', hue='City',data=sales_year_city.topfive, palette='hls')
g.set(xlabel='Year & City', ylabel='Total Sales ($)')
g.set_title('Highest Sales generating top five cities (2014-17)')

# %%
sales_state = orders[['State','Year','Sales']]
sales_year_state = sales_state.groupby(['State','Year'],as_index=False).sum()
sales_year_state.topfive = sales_year_state.sort_values(['Year','Sales'],ascending=[False,False]).groupby('Year').head(5)

# %%
plt.figure(figsize=(15,6))
g= sns.pointplot(x='Year', y='Sales', hue='State',data=sales_year_state.topfive)
g.set(xlabel='Year & State', ylabel='Total Sales ($)')
g.set_title('Highest Sales generating top five states (2014-17)')

# %% [markdown]
# **8. Customers are an important part of an orgnization, they keep the entity running. Let us explore about Office Pro's customers**

# %%
customers = orders[['Customer_ID','Customer_Name','Region','State','City','Category','Sales']]
customers_grouped = customers.groupby(['Customer_ID','Customer_Name','Region','State','City','Category'],as_index=False).sum()
customers_grouped.sort = customers_grouped.sort_values(by='Sales',ascending=False).head(10)

# %%
plt.figure(figsize=(15,6))
sns.set_style('white')
g= sns.barplot(x='Customer_Name', y='Sales',data=customers_grouped.sort)
g.set(xlabel='Customer Name', ylabel='Total Sales ($)')
g.set_title('Top ten Customers from (2014-17)')

# %%
customers_year = orders[['Customer_Name','City','Sales']][(orders['Year'])==2017]
customers_year_grouped = customers_year.groupby(['Customer_Name','City'],as_index=False).sum()
customers_year_grouped_sort = customers_year_grouped.sort_values(by='Sales',ascending=False).head(5)

# %%
plt.figure(figsize=(12,6))
sns.set_style('white')
g= sns.barplot(x='Customer_Name', y='Sales',hue='City',data=customers_year_grouped_sort,color='#34495e')
g.set(xlabel='Customer Name', ylabel='Total Sales ($)')
g.set_title('Top ten Customers in 2017')

# %%
customers_prod = orders[['Customer_Name','Product_Name','Sales']][(orders['Year'])==2017]
customers_prod_grouped = customers_prod.groupby(['Customer_Name','Product_Name'],as_index=False).sum()
customers_prod_grouped_sort = customers_prod_grouped.sort_values(by='Sales',ascending=False).head(5)

# %%
plt.figure(figsize=(12,6))
sns.set_style('white')
g= sns.barplot(x='Product_Name', y='Sales',hue='Product_Name', data=customers_prod_grouped_sort,color='#F08030')
g.set(xlabel='Product Name', ylabel='Average Sales ($)')
g.set_title('Top 5 products bought by Customers in 2017')
#g.set_xticklabels(g.get_xticklabels(),rotation=90)
plt.tick_params(axis='x',bottom='off',labelsize=6)

# %%
cust_returns = orders_r[['Customer_ID','Customer_Name','Year']][(orders_r['Sales']==0)]
cust_returns_grouped = pd.DataFrame({'Returned_Customers_num' : cust_returns.groupby( ['Year','Customer_Name']).size()}).reset_index()
cust_returns_grouped_sort = cust_returns_grouped.sort_values(by='Returned_Customers_num',ascending=False)

# %%
cust_orders = orders_r[['Customer_Name','Year']]
cust_orders_grouped = pd.DataFrame({'Customer_Order_total' : cust_orders.groupby( ['Year','Customer_Name'])
                                     .size()}).reset_index()
cust_orders_grouped_sort = cust_orders_grouped.sort_values(by='Customer_Order_total',ascending=False)

# %%
cust_orders_returns_comb = cust_returns_grouped_sort.merge(cust_orders_grouped_sort,on=['Customer_Name','Year']).head(10)

# %% [markdown]
# ** Ted Butterfield has returned all of the stuff bought from the company in two years.**

# %%
#od = ['Cassandra Brandow','Chuck Magee','Kelly Williams','Anna Andreadi']
f, ax = plt.subplots(figsize=(6, 6))
sns.set_color_codes('pastel')
sns.barplot(x='Customer_Order_total', y='Customer_Name',data=cust_orders_returns_comb,label='Total Orders',color='aqua')
sns.set_color_codes('muted')
sns.barplot(x='Returned_Customers_num', y='Customer_Name',data=cust_orders_returns_comb,label='Total Returns',color='orange')
ax.set(xlabel='Returned & Bought')
ax.set(ylabel='Customer Name')
ax.set_title('Customers with higher returns')
plt.xticks([0,3,6,9,12,15,18,21])
ax.legend(ncol=2, loc="upper right", frameon=True)

# %% [markdown]
# **9. Let us now see how regions are performing**
#
# - _West is the best performing region of all_
# - _ Central saw improvement in 2016 and 2017_

# %%
orders_year = orders[['Region','Year','Sales']]
orders_year_region = orders_year.groupby(['Year','Region'],as_index=False).sum()
orders_year_region_sort = orders_year_region.sort_values(['Year','Sales'],ascending=[False,False]).groupby('Year').head(4)

# %%
plt.figure(figsize=(15,6))
g= sns.barplot(x='Year', y='Sales', hue='Region',data=orders_year_region_sort, palette='deep')
g.set(xlabel='Year & Region', ylabel='Sales')

# %% [markdown]
# ** 10. How are overall sales Office Pro?**
#
# - _The sales went up in 2016, and 2017. Office Pro is in good hands!_

# %%
orders_sales = orders[['Year','Sales']]
orders_sales_cal = orders_sales.groupby('Year',as_index=False).sum()
orders_sales_cal
# Out:
#    Year        Sales
# 0  2014  455027.9501
# 1  2015  430871.6150
# 2  2016  573083.8260
# 3  2017  657713.1913

# %%
plt.figure(figsize=(8,6))
g= sns.barplot(x='Year', y='Sales', data=orders_sales_cal, palette='deep')
g.set(xlabel='Year', ylabel='Total Sales')

# %% [markdown]
# **11. How does the profit look like?**
#
# - _Profits are down in 2017 even though Sales were up from 2016. This directly points to the increarse in number of returns, as the total sum of profits before returns were removed was higher. _|

# %%
orders_profit = orders[['Year','Profit']]
orders_profit_cal = orders_profit.groupby('Year',as_index=False).sum()
orders_profit_cal
# Out:
#    Year      Profit
# 0  2014  49073.2970
# 1  2015  57196.5737
# 2  2016  79182.7886
# 3  2017  77712.0009

# %%
plt.figure(figsize=(8,6))
g= sns.barplot(x='Year', y='Profit', data=orders_profit_cal, palette='muted')
g.set(xlabel='Year', ylabel='Gross Profit')

# %% [markdown]
# **12. Let us calculate the sales to profit ratio**

# %%
orders_profit_sales = orders_profit_cal.merge(orders_sales_cal,on='Year')
orders_profit_sales['Profit_Margin'] = (orders_profit_sales['Profit']/orders_profit_sales['Sales'])
orders_profit_sales
# Out:
#    Year      Profit        Sales  Profit_Margin
# 0  2014  49073.2970  455027.9501       0.107847
# 1  2015  57196.5737  430871.6150       0.132746
# 2  2016  79182.7886  573083.8260       0.138170
# 3  2017  77712.0009  657713.1913       0.118155

# %%
plt.figure(figsize=(8,6))
g= sns.barplot(x='Year', y='Profit_Margin', data=orders_profit_sales, palette='muted')
g.set(xlabel='Year', ylabel='Profit Margin')

# %% [markdown]
# **13. Most discounted products**
# - _Staples and Staple evenlope are most ordered items, they are also most discounted items_
# - _There is a linear relationship between Products discounted most and products ordered most_

# %%
orders_dis = orders[['Order_ID','Product_Name','Discount']][(orders['Discount']>0)]
orders_dis_grouped = orders_dis.groupby(['Product_Name'],as_index=False).count()
#orders_dis_grouped = pd.DataFrame({'Order_count': orders_prodcts.groupby( ['Product_Name'])
 #                                         .count()}).reset_index()
#orders_dis_grouped 
orders_dis_grouped_sorted = orders_dis_grouped.sort_values(by='Discount', ascending=False)

# %%
orders_prodcts = orders[['Product_Name','Order_ID']]
orders_prodcts_grouped = pd.DataFrame({'Order_count': orders_prodcts.groupby( ['Product_Name'])
                                          .size()}).reset_index()
orders_prodcts_grouped_sort = orders_prodcts_grouped.sort_values(by='Order_count',ascending=False)

# %%
discounted_prod = orders_dis_grouped_sorted.merge(orders_prodcts_grouped_sort,on='Product_Name')
discounted_prod['Number_of_times_discounted'] = discounted_prod['Discount']

# %%
discounted_prod_topten= discounted_prod.drop(['Order_ID','Discount'],axis=1).head(10)
discounted_prod_topten
# Out:
#                                         Product_Name  Order_count  \
# 0                                            Staples           44
# 1                            Avery Non-Stick Binders           20
# 2                                    Staple envelope           44
# 3                                  Easy-staple paper           45
# 4                            Storex Dura Pro Binders           17
# 5  GBC Premium Transparent Covers with Diagonal L...           12
# 6                           SAFCO Arco Folding Chair           13
# 7  Avery Self-Adhesive Photo Pockets for Polaroid...           11
# 8    Global Wood Trimmed Manager's Task Chair, Khaki           12
# 9                 Chromcraft Round Conference Tables           13
#
#    Number_of_times_discounted
# 0                          23
# 1                          17
# 2                          16
# 3                          14
# 4                          13
# 5                          12
# ...

# %% [markdown]
# 14.Shipping - average of days in every region

# %%
orders_shipment = orders[['Year','Order_Date','Ship_Date','Ship_Mode','Region','City','Product_Name']]

# %%
orders_shipment['Time_to_ship_Days'] = orders_shipment['Ship_Date'] - orders_shipment['Order_Date']
# Out:
# C:\Users\nikhi_000\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
orders_shipment['Time_to_ship_Days'] = (orders_shipment['Time_to_ship_Days']/np.timedelta64(1,'D')).astype(int)
# Out:
# C:\Users\nikhi_000\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
orders_shipment.Ship_Mode.unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'], dtype=object)

# %%
print(len(orders_shipment[(orders_shipment.Ship_Mode == 'Same Day') & (orders_shipment.Year == 2014)]))
print(len(orders_shipment[(orders_shipment.Ship_Mode == 'Same Day') & (orders_shipment.Year == 2015)]))
print(len(orders_shipment[(orders_shipment.Ship_Mode == 'Same Day') & (orders_shipment.Year == 2016)]))
print(len(orders_shipment[(orders_shipment.Ship_Mode == 'Same Day') & (orders_shipment.Year == 2017)]))
# Out:
# 70
# 91
# 142
# 176

# %%
fc = orders_shipment[(orders_shipment.Ship_Mode == 'First Class') & (orders_shipment.Year == 2014)]
fc.Time_to_ship_Days.unique()
# Out:
# array([2, 3, 1, 4], dtype=int64)

# %%
sc = orders_shipment[(orders_shipment.Ship_Mode == 'Standard Class') & (orders_shipment.Year == 2014)]
sc.Time_to_ship_Days.unique()
# Out:
# array([5, 7, 4, 6], dtype=int64)

# %%
sec = orders_shipment[(orders_shipment.Ship_Mode == 'Second Class') & (orders_shipment.Year == 2014)]
sec.Time_to_ship_Days.unique()
# Out:
# array([2, 5, 4, 3], dtype=int64)

# %%
orders_shipment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9194 entries, 800 to 9993
# Data columns (total 8 columns):
# Year                 9194 non-null int64
# Order_Date           9194 non-null datetime64[ns]
# Ship_Date            9194 non-null datetime64[ns]
# Ship_Mode            9194 non-null object
# Region               9194 non-null object
# City                 9194 non-null object
# Product_Name         9194 non-null object
# Time_to_ship_Days    9194 non-null int32
# dtypes: datetime64[ns](2), int32(1), int64(1), object(4)
# memory usage: 930.5+ KB

# %%
orders_ship_days_region = orders_shipment.groupby(['Year','Region'],as_index=False).mean()
orders_ship_days_sort_reg = orders_ship_days_region.sort_values(by='Time_to_ship_Days',ascending=False)
orders_ship_days_sort_reg
# Out:
#     Year   Region  Time_to_ship_Days
# 6   2015    South           4.256173
# 0   2014  Central           4.200000
# 8   2016  Central           4.156729
# 3   2014     West           4.060449
# 7   2015     West           4.059891
# 4   2015  Central           4.043764
# 11  2016     West           4.035398
# 12  2017  Central           3.961178
# 1   2014     East           3.954918
# 13  2017     East           3.949599
# 14  2017    South           3.893574
# 9   2016     East           3.860465
# 2   2014    South           3.853731
# 5   2015     East           3.853377
# 15  2017     West           3.808840
# 10  2016    South           3.748731

# %%
orders_ship_days_sort_prod = orders_ship_days.sort_values(by='Time_to_ship_Days',ascending=False)

# %%
orders_ship_days_sort_prod.head(20)
# Out:
#       Year                                       Product_Name  \
# 4991  2017  Self-Adhesive Address Labels for Typewriters b...
# 1516  2015                                      Crate-A-Files
# 953   2014                   Seth Thomas 8 1/2" Cubicle Clock
# 4120  2017  Boston Heavy-Duty Trimline Electric Pencil Sha...
# 669   2014                     Logitech Trackman Marble Mouse
# 666   2014  Logitech Illuminated Ultrathin Keyboard with B...
# 4976  2017  Sanford Uni-Blazer View Highlighters, Chisel T...
# 955   2014                     Sharp AL-1530CS Digital Copier
# 2738  2016  Bush Advantage Collection Racetrack Conference...
# 641   2014          Kingston Digital DataTraveler 8GB USB 2.0
# 2729  2016      Bretford CR4500 Series Slim Rectangular Table
# 4178  2017                 Cisco IP Phone 7961G-GE VoIP phone
# 1508  2015           Compact Automatic Electric Letter Opener
# 2728  2016  Bravo II Megaboss 12-Amp Hard Body Upright, Re...
# ...

# %%
#orders_year = orders[orders['Year']==2017]
# Quota each region
orders_year = orders
orders_quota = orders_year.merge(quota,on='State')
orders_people = orders_quota.merge(people,on='Region')
orders_final = orders_people[['Region','State','Sales_Person','Quota','Sales']]

# %%
orders_final_grouped = orders_final.groupby(['Region','State','Sales_Person','Quota'],as_index=False).sum()
orders_final_grouped.round(2)
# Out:
#      Region                 State       Sales_Person    Quota      Sales
# 0   Central              Illinois     Kelly Williams   500000   78211.81
# 1   Central               Indiana     Kelly Williams   220000   52891.15
# 2   Central                  Iowa     Kelly Williams    71000    4579.76
# 3   Central                Kansas     Kelly Williams   125000    2914.31
# 4   Central              Michigan     Kelly Williams   335000   74698.10
# 5   Central             Minnesota     Kelly Williams   175000   29820.15
# 6   Central              Missouri     Kelly Williams   100000   22179.23
# 7   Central              Nebraska     Kelly Williams    42000    7430.43
# 8   Central          North Dakota     Kelly Williams    25000     919.91
# 9   Central              Oklahoma     Kelly Williams    64000   19502.72
# 10  Central          South Dakota     Kelly Williams    32000    1315.56
# 11  Central                 Texas     Kelly Williams   700000  160989.32
# ...

# %%
orders_final_grouped = orders_final.groupby(['Region','Sales_Person','Quota']).sum()
orders_final_grouped.round(2)
# Out:
#                                        Sales
# Region  Sales_Person      Quota
# Central Kelly Williams    25000       919.91
#                           32000      1315.56
#                           42000      7430.43
#                           64000     19502.72
#                           71000      4579.76
#                           100000    22179.23
#                           125000     2914.31
#                           150000    31780.46
#                           175000    29820.15
#                           220000    52891.15
#                           335000    74698.10
#                           500000    78211.81
#                           700000   160989.32
# East    Chuck Magee       19500     22028.06
#                           34500      1209.82
#                           37000      8929.37
#                           39000      6567.97
#                           50000     13384.36
#                           90000      1270.53
# ...

# %%
orders_year1 = orders
orders_quota1 = orders_year.merge(quota,on='State')
orders_people1 = orders_quota.merge(people,on='Region')
orders_final1 = orders_people[['Region','State','Sales_Person','Quota','Sales']]
orders_final1.head()
# Out:
#   Region     State       Sales_Person  Quota   Sales
# 0  South  Kentucky  Cassandra Brandow  70000  261.96
# 1  South  Kentucky  Cassandra Brandow  70000  731.94
# 2  South  Kentucky  Cassandra Brandow  70000    5.78
# 3  South  Kentucky  Cassandra Brandow  70000  152.94
# 4  South  Kentucky  Cassandra Brandow  70000  283.92

# %%
orders_final1_grouped = orders_final.groupby(['Region','Sales_Person','Quota'],as_index=False).sum()
orders_final1_grouped.round(2)
# Out:
#      Region       Sales_Person    Quota      Sales
# 0   Central     Kelly Williams    25000     919.91
# 1   Central     Kelly Williams    32000    1315.56
# 2   Central     Kelly Williams    42000    7430.43
# 3   Central     Kelly Williams    64000   19502.72
# 4   Central     Kelly Williams    71000    4579.76
# 5   Central     Kelly Williams   100000   22179.23
# 6   Central     Kelly Williams   125000    2914.31
# 7   Central     Kelly Williams   150000   31780.46
# 8   Central     Kelly Williams   175000   29820.15
# 9   Central     Kelly Williams   220000   52891.15
# 10  Central     Kelly Williams   335000   74698.10
# 11  Central     Kelly Williams   500000   78211.81
# 12  Central     Kelly Williams   700000  160989.32
# 13     East        Chuck Magee    19500   22028.06
# 14     East        Chuck Magee    34500    1209.82
# 15     East        Chuck Magee    37000    8929.37
# 16     East        Chuck Magee    39000    6567.97
# ...

# %%
orders_final_grouped_Central = orders_final1_grouped[orders_final1_grouped['Region']=='Central']
orders_final_grouped_Central_grouped = orders_final_grouped_Central.groupby(['Region','Sales_Person'],as_index=False).sum()
orders_final_grouped_Central_grouped
# Out:
#     Region    Sales_Person    Quota        Sales
# 0  Central  Kelly Williams  2539000  487232.9114

# %%
orders_final_grouped_West = orders_final1_grouped[orders_final1_grouped['Region']=='West']
orders_final_grouped_West_grouped = orders_final_grouped_West.groupby(['Region','Sales_Person'],as_index=False).sum()
orders_final_grouped_West_grouped
# Out:
#   Region   Sales_Person    Quota       Sales
# 0   West  Anna Andreadi  2741000  617974.767

# %%
orders_final_grouped_East = orders_final1_grouped[orders_final1_grouped['Region']=='East']
orders_final_grouped_East_grouped = orders_final_grouped_East.groupby(['Region','Sales_Person'],as_index=False).sum()
orders_final_grouped_East_grouped
# Out:
#   Region Sales_Person    Quota      Sales
# 0   East  Chuck Magee  2838000  611964.75

# %%
orders_final_grouped_South = orders_final1_grouped[orders_final1_grouped['Region']=='South']
orders_final_grouped_South_grouped = orders_final_grouped_South.groupby(['Region','Sales_Person'],as_index=False).sum()
orders_final_grouped_South_grouped
# Out:
#   Region       Sales_Person    Quota       Sales
# 0  South  Cassandra Brandow  1594500  374412.808

# %%
result = pd.concat([orders_final_grouped_Central_grouped, orders_final_grouped_West_grouped, 
                                 orders_final_grouped_East_grouped, orders_final_grouped_South_grouped])

result.round(2)
# Out:
#     Region       Sales_Person    Quota      Sales
# 0  Central     Kelly Williams  2539000  487232.91
# 0     West      Anna Andreadi  2741000  617974.77
# 0     East        Chuck Magee  2838000  611964.75
# 0    South  Cassandra Brandow  1594500  374412.81

# %%
result['Quota_ratio'] = result['Sales']/result['Quota']

# %%
result.round(2)
# Out:
#     Region       Sales_Person    Quota      Sales  Quota_ratio
# 0  Central     Kelly Williams  2539000  487232.91         0.19
# 0     West      Anna Andreadi  2741000  617974.77         0.23
# 0     East        Chuck Magee  2838000  611964.75         0.22
# 0    South  Cassandra Brandow  1594500  374412.81         0.23

# %% [markdown]
# **Sales Quota seems to be too agressive, the highest quota met is 23%**

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.set_color_codes('pastel')
sns.barplot(x='Quota', y='Sales_Person',data=result,label='Quota',color='aqua')
sns.set_color_codes('muted')
sns.barplot(x='Sales', y='Sales_Person',data=result,label='Sales',color='orange')
ax.set(xlabel='Sales & Quota')
ax.legend(ncol=2, loc="lower right", frameon=True)
